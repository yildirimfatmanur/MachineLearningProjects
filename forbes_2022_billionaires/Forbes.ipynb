# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("forbes_2022_billionaires.csv")

# %%
df
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
df.loc[0:5,"age":"country"]
# Out:
#     age  finalWorth  year  month               category              source  \
# 0  50.0    219000.0  2022      4             Automotive       Tesla, SpaceX
# 1  58.0    171000.0  2022      4             Technology              Amazon
# 2  73.0    158000.0  2022      4       Fashion & Retail                LVMH
# 3  66.0    129000.0  2022      4             Technology           Microsoft
# 4  91.0    118000.0  2022      4  Finance & Investments  Berkshire Hathaway
# 5  49.0    111000.0  2022      4             Technology              Google
#
#          country
# 0  United States
# 1  United States
# 2         France
# 3  United States
# 4  United States
# 5  United States

# %%
df.shape # 2668 satir 22 sutun var
# Out:
# (2668, 22)

# %%
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')

# %%
df.iloc[:,2:5]
# Out:
#        age  finalWorth  year
# 0     50.0    219000.0  2022
# 1     58.0    171000.0  2022
# 2     73.0    158000.0  2022
# 3     66.0    129000.0  2022
# 4     91.0    118000.0  2022
# ...    ...         ...   ...
# 2663  66.0      1000.0  2022
# 2664  59.0      1000.0  2022
# 2665  57.0      1000.0  2022
# 2666  43.0      1000.0  2022
# 2667  59.0      1000.0  2022
#
# [2668 rows x 3 columns]

# %%
df = df.loc[:,["rank","personName","age","finalWorth","category","country","gender"]]

# %%
df = df.rename(columns={"rank":"sira","personName":"isim","age":"yas","finalWorth":"servet","category":"kategori",
                       "country":"ulke","gender":"cinsiyet"})

# %%
df.head()
# Out:
#    sira                      isim   yas    servet               kategori  \
# 0     1                 Elon Musk  50.0  219000.0             Automotive
# 1     2                Jeff Bezos  58.0  171000.0             Technology
# 2     3  Bernard Arnault & family  73.0  158000.0       Fashion & Retail
# 3     4                Bill Gates  66.0  129000.0             Technology
# 4     5            Warren Buffett  91.0  118000.0  Finance & Investments
#
#             ulke cinsiyet
# 0  United States        M
# 1  United States        M
# 2         France        M
# 3  United States        M
# 4  United States        M

# %%
df=df.set_index("sira") # sirayi index haline getirdik

# %%
df.dtypes
# Out:
# isim         object
# yas         float64
# servet      float64
# kategori     object
# ulke         object
# cinsiyet     object
# dtype: object

# %%
#df.isnull() true ya da false donduruyor df.dropna(inplace=True) dersek butun nan degerler silinir

# %%
df.isnull().sum()
# Out:
# isim         0
# yas         86
# servet       0
# kategori     0
# ulke        13
# cinsiyet    16
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum() # nan degerler silindi
# Out:
# isim        0
# yas         0
# servet      0
# kategori    0
# ulke        0
# cinsiyet    0
# dtype: int64

# %%
df["cinsiyet"].value_counts()
# Out:
# M    2282
# F     286
# Name: cinsiyet, dtype: int64

# %%
df["cinsiyet"].value_counts(normalize=True)
# Out:
# M    0.888629
# F    0.111371
# Name: cinsiyet, dtype: float64

# %%
df[df["ulke"] == "Turkey"].cinsiyet.value_counts()
# Out:
# M    19
# F     4
# Name: cinsiyet, dtype: int64

# %%
df["ulke"].unique()
# Out:
# array(['United States', 'France', 'India', 'Mexico', 'China', 'Singapore',
#        'Spain', 'Canada', 'Germany', 'Switzerland', 'Belgium',
#        'Hong Kong', 'United Kingdom', 'Australia', 'Austria', 'Italy',
#        'Japan', 'Bahamas', 'Indonesia', 'Chile', 'Russia', 'Sweden',
#        'Czechia', 'Monaco', 'United Arab Emirates', 'Nigeria', 'Denmark',
#        'Thailand', 'Malaysia', 'Brazil', 'Colombia', 'New Zealand',
#        'South Korea', 'South Africa', 'Philippines', 'Egypt', 'Taiwan',
#        'Israel', 'Vietnam', 'Poland', 'Norway', 'Cayman Islands',
#        'Netherlands', 'Eswatini (Swaziland)', 'Peru', 'Algeria',
#        'Kazakhstan', 'Georgia', 'Portugal', 'British Virgin Islands',
#        'Turkey', 'Finland', 'Ukraine', 'Ireland', 'Bermuda', 'Lebanon',
#        'Argentina', 'Cambodia', 'Oman', 'Guernsey', 'Liechtenstein',
#        'Turks and Caicos Islands', 'Qatar', 'Morocco', 'Uruguay',
#        'Slovakia', 'Romania', 'Nepal', 'Tanzania', 'Bahrain', 'Greece',
# ...

# %%
df[df["ulke"] == "France"].cinsiyet.value_counts(normalize=True)
# Out:
# M    0.878788
# F    0.121212
# Name: cinsiyet, dtype: float64

# %%
df_cinsiyet = df.groupby(["cinsiyet"])

# %%
df_cinsiyet["yas"].mean() # yas yerine string bir deger olan bir sey yazamazsın ort alamaz
# Out:
# cinsiyet
# F    62.937063
# M    64.409290
# Name: yas, dtype: float64

# %%
import seaborn as sns

# %%
sns.set_theme() # temayi ayarliyoruz

# %%
sns.set(rc = {"figure.dpi":300})

# %%
df_cinsiyet.size().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='cinsiyet'>

# %%
plt.plot(df["servet"][:10],df["isim"][:10])

# %%
import seaborn as sns

# %%
sns.barplot(y=df["isim"][:10],x =df["servet"][:10])
# Out:
# <AxesSubplot:xlabel='servet', ylabel='isim'>

# %%
len(df["ulke"].unique())
# Out:
# 73

# %%
df_ulke = df.groupby("ulke")

# %%
df_ulke_sayi = pd.DataFrame(df_ulke.size().sort_values(ascending= False),columns=["Sayi"])

# %%
df_ulke_sayi.head(10) # ilk 10 ulkeyi aldik
# Out:
#                 Sayi
# ulke
# United States    742
# China            546
# India            154
# Germany           94
# United Kingdom    81
# Switzerland       70
# Hong Kong         66
# Russia            65
# Brazil            53
# Italy             49

# %%
# en fazla zenginin bulundugu ulke amerika

# %%
sns.barplot(x=df_ulke_sayi["Sayi"][:10],y=df_ulke_sayi.index[:10])
# Out:
# <AxesSubplot:xlabel='Sayi', ylabel='ulke'>

# %%
df_turkiye = df[df["ulke"]=="Turkey"]

# %%
df_turkiye["isim"].count()
# Out:
# 23

# %%
df_turkiye.head(10)
# Out:
#                      isim   yas  servet                    kategori    ulke  \
# sira
# 601           Murat Ulker  63.0  4700.0             Food & Beverage  Turkey
# 1292    Ferit Faik Sahenk  58.0  2400.0                 Diversified  Turkey
# 1341         Erman Ilicak  54.0  2300.0  Construction & Engineering  Turkey
# 1397         Filiz Sahenk  55.0  2200.0                 Diversified  Turkey
# 1579       Sezai Bacaksiz  72.0  1900.0                 Diversified  Turkey
# 1579        Nihat Ozdemir  72.0  1900.0                 Diversified  Turkey
# 1645    Ibrahim Erdemoglu  59.0  1800.0               Manufacturing  Turkey
# 1818  Semahat Sevim Arsel  93.0  1600.0                 Diversified  Turkey
# 1929  Hamdi Akin & family  67.0  1500.0                 Diversified  Turkey
# 1929          Ahmet Calik  64.0  1500.0                 Diversified  Turkey
#
#      cinsiyet
# sira
# 601         M
# 1292        M
# 1341        M
# 1397        F
# 1579        M
# 1579        M
# ...

# %%
sns.barplot(y=df_turkiye["isim"][:10],x = df_turkiye["servet"][:10])
# Out:
# <AxesSubplot:xlabel='servet', ylabel='isim'>

# %%
df["kategori"].unique()
# Out:
# array(['Automotive', 'Technology', 'Fashion & Retail',
#        'Finance & Investments', 'Diversified', 'Media & Entertainment',
#        'Telecom', 'Food & Beverage', 'Logistics', 'Real Estate',
#        'Metals & Mining', 'Manufacturing', 'Gambling & Casinos',
#        'Healthcare', 'Service', 'Energy', 'Construction & Engineering',
#        'Sports'], dtype=object)

# %%
df["kategori"] = df["kategori"].apply(lambda x:x.replace(" ","")).apply(lambda x:x.replace("&","_"))

# %%
df["kategori"].unique()
# Out:
# array(['Automotive', 'Technology', 'Fashion_Retail',
#        'Finance_Investments', 'Diversified', 'Media_Entertainment',
#        'Telecom', 'Food_Beverage', 'Logistics', 'RealEstate',
#        'Metals_Mining', 'Manufacturing', 'Gambling_Casinos', 'Healthcare',
#        'Service', 'Energy', 'Construction_Engineering', 'Sports'],
#       dtype=object)

# %%
df_kategori = df.groupby("kategori").size()

# %%
df_kategori.head(10)
# Out:
# kategori
# Automotive                   66
# Construction_Engineering     45
# Diversified                 174
# Energy                       93
# Fashion_Retail              238
# Finance_Investments         381
# Food_Beverage               193
# Gambling_Casinos             23
# Healthcare                  209
# Logistics                    32
# dtype: int64

# %%
df_kategori = df_kategori.to_frame()

# %%
df_kategori.head()
# Out:
#                             0
# kategori
# Automotive                 66
# Construction_Engineering   45
# Diversified               174
# Energy                     93
# Fashion_Retail            238

# %%
df_kategori = df_kategori.rename(columns={0:"Sayi"}).sort_values(by="Sayi",ascending = False)

# %%
df_kategori.head()
# Out:
#                      Sayi
# kategori
# Finance_Investments   381
# Technology            332
# Manufacturing         319
# Fashion_Retail        238
# Healthcare            209

# %%
sns.barplot(x=df_kategori["Sayi"][:10], y= df_kategori.index[:10])
# Out:
# <AxesSubplot:xlabel='Sayi', ylabel='kategori'>

# %%
# yas ile zenginlik arasinda bir iliski var mi ona bakacagiz

# %%
sns.scatterplot(df["yas"],df["servet"])
# Out:
# C:\Users\fatmanur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='yas', ylabel='servet'>

# %%
# herhangi bir iliski yok

# %%
sns.histplot(df["yas"]) # yolcularin yas dagilimi (eksik verileri icermiyor)
# Out:
# <AxesSubplot:xlabel='yas', ylabel='Count'>

# %%
df_yas = data.sort_values(by)
