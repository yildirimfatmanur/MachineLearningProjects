# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
games = pd.read_csv("vgsalesGlobale.csv",index_col="Name") # name veri setinin indexi oldu

# %%
games.head(10)
# Out:
#                            Rank Platform    Year         Genre Publisher  \
# Name
# Wii Sports                    1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.             2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii                3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort             4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue      5       GB  1996.0  Role-Playing  Nintendo
# Tetris                        6       GB  1989.0        Puzzle  Nintendo
# New Super Mario Bros.         7       DS  2006.0      Platform  Nintendo
# Wii Play                      8      Wii  2006.0          Misc  Nintendo
# New Super Mario Bros. Wii     9      Wii  2009.0      Platform  Nintendo
# Duck Hunt                    10      NES  1984.0       Shooter  Nintendo
#
#                            NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                    41.49     29.02      3.77         8.46
# ...

# %%
# tek bir sütundan olusan veri yapısına series denir excel gibi tablo seklinde olan da dataframe

# %%
games.tail(10) # sondan 10 elemana bakar
# Out:
#                                                      Rank Platform    Year  \
# Name
# Mega Brain Boost                                    16591       DS  2008.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
# Eiyuu Densetsu: Sora no Kiseki Material Collect...  16593      PSP  2007.0
# Myst IV: Revelation                                 16594       PC  2004.0
# Plushees                                            16595       DS  2008.0
# Woody Woodpecker in Crazy Castle 5                  16596      GBA  2002.0
# Men in Black II: Alien Escape                       16597       GC  2003.0
# SCORE International Baja 1000: The Official Game    16598      PS2  2008.0
# Know How 2                                          16599       DS  2010.0
# Spirits & Spells                                    16600      GBA  2003.0
#
#                                                            Genre  \
# Name
# ...

# %%
games.shape
# Out:
# (16598, 10)

# %%
games.dtypes
# Out:
# Rank              int64
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
# csv dosyasını excele donusturdugumuzde float 64 olan bazı degerler int e donustu sebep??

# %%
games.iloc[299] # 300.satiri basiyoruz
# Out:
# Rank                           300
# Platform                       PS3
# Year                        2008.0
# Genre                 Role-Playing
# Publisher       Bethesda Softworks
# NA_Sales                      2.15
# EU_Sales                       1.2
# JP_Sales                      0.07
# Other_Sales                   0.59
# Global_Sales                  4.01
# Name: Fallout 3, dtype: object

# %%
games.loc["Super Mario Bros."]
# Out:
#                    Rank Platform    Year     Genre Publisher  NA_Sales  \
# Name
# Super Mario Bros.     2      NES  1985.0  Platform  Nintendo     29.08
# Super Mario Bros.   201       GB  1999.0  Platform  Nintendo      3.40
#
#                    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Name
# Super Mario Bros.      3.58      6.81         0.77         40.24
# Super Mario Bros.      1.30      0.15         0.22          5.07

# %%
games.loc["Super Mario Bros.","Rank"]
# Out:
# Name
# Super Mario Bros.      2
# Super Mario Bros.    201
# Name: Rank, dtype: int64

# %%
games.loc["Super Mario Bros.","Genre"]
# Out:
# Name
# Super Mario Bros.    Platform
# Super Mario Bros.    Platform
# Name: Genre, dtype: object

# %%
games.sort_values(by = "Year")
# Out:
#                               Rank Platform    Year         Genre  \
# Name
# Checkers                      6898     2600  1980.0          Misc
# Boxing                        2671     2600  1980.0      Fighting
# Freeway                       5368     2600  1980.0        Action
# Defender                      1971     2600  1980.0          Misc
# Kaboom!                       1768     2600  1980.0          Misc
# ...                            ...      ...     ...           ...
# Freaky Flyers                16310       GC     NaN        Racing
# Inversion                    16330       PC     NaN       Shooter
# Hakuouki: Shinsengumi Kitan  16369      PS3     NaN     Adventure
# Virtua Quest                 16430       GC     NaN  Role-Playing
# The Smurfs                   16496      3DS     NaN        Action
#
#                                       Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# Checkers                                  Atari      0.22      0.01       0.0
# ...

# %%
games.sort_values(by = "Year",ascending=False)
# Out:
#                                                    Rank Platform    Year  \
# Name
# Imagine: Makeup Artist                             5959       DS  2020.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  14393      PS4  2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  16244      PSV  2017.0
# Brothers Conflict: Precious Baby                  16441      PSV  2017.0
# Shin Megami Tensei IV: Final                       8295      3DS  2016.0
# ...                                                 ...      ...     ...
# Freaky Flyers                                     16310       GC     NaN
# Inversion                                         16330       PC     NaN
# Hakuouki: Shinsengumi Kitan                       16369      PS3     NaN
# Virtua Quest                                      16430       GC     NaN
# The Smurfs                                        16496      3DS     NaN
#
#                                                          Genre  \
# Name
# ...

# %%
games.sort_values(by = ["Year","Genre"],ascending=False).head()
# Out:
#                                                    Rank Platform    Year  \
# Name
# Imagine: Makeup Artist                             5959       DS  2020.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  14393      PS4  2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  16244      PSV  2017.0
# Brothers Conflict: Precious Baby                  16441      PSV  2017.0
# XCOM 2                                             7566       PC  2016.0
#
#                                                          Genre  \
# Name
# Imagine: Makeup Artist                              Simulation
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing
# Brothers Conflict: Precious Baby                        Action
# XCOM 2                                                Strategy
#
#                                                              Publisher  \
# Name
# ...

# %%
games.loc["Super Mario Bros.",["Genre","Year","Platform"]]
# Out:
#                       Genre    Year Platform
# Name
# Super Mario Bros.  Platform  1985.0      NES
# Super Mario Bros.  Platform  1999.0       GB

# %%
games["Publisher"].head() #  bu bir seriestir
# Out:
# Name
# Wii Sports                  Nintendo
# Super Mario Bros.           Nintendo
# Mario Kart Wii              Nintendo
# Wii Sports Resort           Nintendo
# Pokemon Red/Pokemon Blue    Nintendo
# Name: Publisher, dtype: object

# %%
games["Year"].head()
# Out:
# Name
# Wii Sports                  2006.0
# Super Mario Bros.           1985.0
# Mario Kart Wii              2008.0
# Wii Sports Resort           2009.0
# Pokemon Red/Pokemon Blue    1996.0
# Name: Year, dtype: float64

# %%
games[games["Genre"] == "Action"].head()
# Out:
#                                Rank Platform    Year   Genre  \
# Name
# Grand Theft Auto V               17      PS3  2013.0  Action
# Grand Theft Auto: San Andreas    18      PS2  2004.0  Action
# Grand Theft Auto V               24     X360  2013.0  Action
# Grand Theft Auto: Vice City      25      PS2  2002.0  Action
# Grand Theft Auto III             39      PS2  2001.0  Action
#
#                                           Publisher  NA_Sales  EU_Sales  \
# Name
# Grand Theft Auto V             Take-Two Interactive      7.01      9.27
# Grand Theft Auto: San Andreas  Take-Two Interactive      9.43      0.40
# Grand Theft Auto V             Take-Two Interactive      9.63      5.31
# Grand Theft Auto: Vice City    Take-Two Interactive      8.41      5.49
# Grand Theft Auto III           Take-Two Interactive      6.99      4.51
#
#                                JP_Sales  Other_Sales  Global_Sales
# Name
# Grand Theft Auto V                 0.97         4.14         21.40
# ...

# %%
(games["Genre"] == "Action").dtypes
# Out:
# dtype('bool')

# %%
games_in_2010 = games["Year"]==2010

# %%
games[games_in_2010].head()
# Out:
#                              Rank Platform    Year         Genre  \
# Name
# Kinect Adventures!             16     X360  2010.0          Misc
# Pokemon Black/Pokemon White    27       DS  2010.0  Role-Playing
# Call of Duty: Black Ops        32     X360  2010.0       Shooter
# Call of Duty: Black Ops        41      PS3  2010.0       Shooter
# Gran Turismo 5                 55      PS3  2010.0        Racing
#
#                                                Publisher  NA_Sales  EU_Sales  \
# Name
# Kinect Adventures!                Microsoft Game Studios     14.97      4.94
# Pokemon Black/Pokemon White                     Nintendo      5.57      3.28
# Call of Duty: Black Ops                       Activision      9.67      3.73
# Call of Duty: Black Ops                       Activision      5.98      4.44
# Gran Turismo 5               Sony Computer Entertainment      2.96      4.88
#
#                              JP_Sales  Other_Sales  Global_Sales
# Name
# ...

# %%
games_action = games["Genre"] == "Action"

# %%
games[games_in_2010 & games_action].head() # 2010 yılı Action turundeki oyunlar
# Out:
#                                Rank Platform    Year   Genre  \
# Name
# Red Dead Redemption             124      PS3  2010.0  Action
# Red Dead Redemption             135     X360  2010.0  Action
# God of War III                  217      PS3  2010.0  Action
# Assassin's Creed: Brotherhood   374     X360  2010.0  Action
# Assassin's Creed: Brotherhood   515      PS3  2010.0  Action
#
#                                                  Publisher  NA_Sales  \
# Name
# Red Dead Redemption                   Take-Two Interactive      2.79
# Red Dead Redemption                   Take-Two Interactive      3.70
# God of War III                 Sony Computer Entertainment      2.74
# Assassin's Creed: Brotherhood                      Ubisoft      2.84
# Assassin's Creed: Brotherhood                      Ubisoft      1.87
#
#                                EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Name
# Red Dead Redemption                2.61      0.17         1.03          6.60
# ...

# %%
games[games_in_2010 | games_action].head()
# Out:
#                                Rank Platform    Year   Genre  \
# Name
# Kinect Adventures!               16     X360  2010.0    Misc
# Grand Theft Auto V               17      PS3  2013.0  Action
# Grand Theft Auto: San Andreas    18      PS2  2004.0  Action
# Grand Theft Auto V               24     X360  2013.0  Action
# Grand Theft Auto: Vice City      25      PS2  2002.0  Action
#
#                                             Publisher  NA_Sales  EU_Sales  \
# Name
# Kinect Adventures!             Microsoft Game Studios     14.97      4.94
# Grand Theft Auto V               Take-Two Interactive      7.01      9.27
# Grand Theft Auto: San Andreas    Take-Two Interactive      9.43      0.40
# Grand Theft Auto V               Take-Two Interactive      9.63      5.31
# Grand Theft Auto: Vice City      Take-Two Interactive      8.41      5.49
#
#                                JP_Sales  Other_Sales  Global_Sales
# Name
# ...

# %%
""" & = ve  |=veya """
# Out:
# ' & = ve  |=veya '

# %%
after_2015 = games[games["Year"]>2015]

# %%
after_2015.head()
# Out:
#                             Rank Platform    Year    Genre  \
# Name
# FIFA 17                      222      PS4  2016.0   Sports
# Uncharted 4: A Thief's End   272      PS4  2016.0  Shooter
# Tom Clancy's The Division    352      PS4  2016.0  Shooter
# Far Cry: Primal              772      PS4  2016.0   Action
# Tom Clancy's The Division    847     XOne  2016.0  Shooter
#
#                                               Publisher  NA_Sales  EU_Sales  \
# Name
# FIFA 17                                 Electronic Arts      0.28      3.75
# Uncharted 4: A Thief's End  Sony Computer Entertainment      1.30      2.07
# Tom Clancy's The Division                       Ubisoft      1.28      1.61
# Far Cry: Primal                                 Ubisoft      0.59      1.16
# Tom Clancy's The Division                       Ubisoft      1.20      0.62
#
#                             JP_Sales  Other_Sales  Global_Sales
# Name
# FIFA 17                         0.06         0.69          4.77
# ...

# %%
mid_2000 = games[games["Year"].between(2000,2010)]

# %%
mid_2000
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# New Super Mario Bros.                                 7       DS  2006.0
# Wii Play                                              8      Wii  2006.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                      Genre   Publisher  \
# Name
# ...

# %%
sport_in_title = games.index.str.lower().str.contains("sport")

# %%
games[sport_in_title] # icinde sport gecen oyunlar
# Out:
#                                                 Rank Platform    Year   Genre  \
# Name
# Wii Sports                                         1      Wii  2006.0  Sports
# Wii Sports Resort                                  4      Wii  2009.0  Sports
# Kinect Sports                                    140     X360  2010.0  Sports
# Forza Motorsport 3                               161     X360  2009.0  Racing
# Forza Motorsport 4                               229     X360  2011.0  Racing
# ...                                              ...      ...     ...     ...
# Disney Sports Football                         15664       GC  2002.0  Sports
# Winter Sports 3: The Great Tournament          15823     X360  2010.0  Sports
# IHRA Drag Racing: Sportsman Edition            15957       XB  2006.0  Racing
# RalliSport Challenge(JP sales)                 16328       XB  2002.0  Racing
# Original Frisbee Disc Sports: Ultimate & Golf  16567       DS  2007.0  Action
#
# ...

# %%
games["Global_Sales"].mean()
# Out:
# 0.53744065550074

# %%
genres = games.groupby("Genre")

# %%
genres["Global_Sales"].sum()
# Out:
# Genre
# Action          1751.18
# Adventure        239.04
# Fighting         448.91
# Misc             809.96
# Platform         831.37
# Puzzle           244.95
# Racing           732.04
# Role-Playing     927.37
# Shooter         1037.37
# Simulation       392.20
# Sports          1330.93
# Strategy         175.12
# Name: Global_Sales, dtype: float64

# %%
genres["Global_Sales"].sum().sort_values(ascending = False)
# Out:
# Genre
# Action          1751.18
# Sports          1330.93
# Shooter         1037.37
# Role-Playing     927.37
# Platform         831.37
# Misc             809.96
# Racing           732.04
# Fighting         448.91
# Simulation       392.20
# Puzzle           244.95
# Adventure        239.04
# Strategy         175.12
# Name: Global_Sales, dtype: float64

# %%
#Series bir boyutludur dataframe iki boyutlu

# %%
games.Global_Sales.head()
# Out:
# Name
# Wii Sports                  82.74
# Super Mario Bros.           40.24
# Mario Kart Wii              35.82
# Wii Sports Resort           33.00
# Pokemon Red/Pokemon Blue    31.37
# Name: Global_Sales, dtype: float64

# %%
games["Global_Sales"].head()
# Out:
# Name
# Wii Sports                  82.74
# Super Mario Bros.           40.24
# Mario Kart Wii              35.82
# Wii Sports Resort           33.00
# Pokemon Red/Pokemon Blue    31.37
# Name: Global_Sales, dtype: float64

# %%
games[["Global_Sales","Genre","Year"]].head()
# Out:
#                           Global_Sales         Genre    Year
# Name
# Wii Sports                       82.74        Sports  2006.0
# Super Mario Bros.                40.24      Platform  1985.0
# Mario Kart Wii                   35.82        Racing  2008.0
# Wii Sports Resort                33.00        Sports  2009.0
# Pokemon Red/Pokemon Blue         31.37  Role-Playing  1996.0

# %%
# loc komutunda satir ve sutun isimleri girilerek secme yapilir 
# iloc komutunda satir ve sutun indexlerli girilir ilk parametre satir ikinic sutun

# %%
games.iloc[0]
# Out:
# Rank                   1
# Platform             Wii
# Year              2006.0
# Genre             Sports
# Publisher       Nintendo
# NA_Sales           41.49
# EU_Sales           29.02
# JP_Sales            3.77
# Other_Sales         8.46
# Global_Sales       82.74
# Name: Wii Sports, dtype: object

# %%
games.iloc[0,2]
# Out:
# 2006.0

# %%
games.iloc[0,[0,2,3]]
# Out:
# Rank          1
# Year     2006.0
# Genre    Sports
# Name: Wii Sports, dtype: object

# %%
games.iloc[0:3,[0,2,3]] # 1. satirdan 3.satira kadar olan satirdaki 1.3.ve4. sutunlari basar
# Out:
#                    Rank    Year     Genre
# Name
# Wii Sports            1  2006.0    Sports
# Super Mario Bros.     2  1985.0  Platform
# Mario Kart Wii        3  2008.0    Racing

# %%
games.iloc[0:3,1:4]
# Out:
#                   Platform    Year     Genre
# Name
# Wii Sports             Wii  2006.0    Sports
# Super Mario Bros.      NES  1985.0  Platform
# Mario Kart Wii         Wii  2008.0    Racing

# %%
games = pd.read_csv("vgsalesGlobale.csv") # name veri setinin indexi oldu
#games = pd.read_csv("vgsalesGlobale.csv",index_col="Name") # name veri setinin indexi oldu
# boyle oldugu zaman asagidaki gibi indexleme yapamiyoruz cunku indeximiz stringe donusmus oluyor
games.loc[0:5,"Rank":"Genre"]
# Out:
#    Rank                      Name Platform    Year         Genre
# 0     1                Wii Sports      Wii  2006.0        Sports
# 1     2         Super Mario Bros.      NES  1985.0      Platform
# 2     3            Mario Kart Wii      Wii  2008.0        Racing
# 3     4         Wii Sports Resort      Wii  2009.0        Sports
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 5     6                    Tetris       GB  1989.0        Puzzle

# %%
games.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
games.dropna(axis=0).shape
# Out:
# (16291, 11)

# %%
games.dropna(axis=1,how = "any").shape
# Out:
# (16598, 9)

# %%
games.dropna(axis="columns",how = "any").shape
# Out:
# (16598, 9)

# %%
games.dropna(axis="rows",how = "any").shape
# Out:
# (16291, 11)

# %%
games.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64
